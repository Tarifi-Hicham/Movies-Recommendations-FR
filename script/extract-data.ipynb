# %%
import pandas as pd
import requests
import json
import os
from hdfs import InsecureClient
from dotenv import load_dotenv
from datetime import datetime, timedelta


def get_last_api_page(user_name):
    directory_path = f'/user/{user_name}'
    directories = client.list(directory_path, status=True)
    sorted_directories = sorted(directories, key=lambda x: x[1]['modificationTime'], reverse=True)
    last_directory_date = sorted_directories[0][0]
    directory_path = f'/user/{user_name}/{last_directory_date}'
    directories = client.list(directory_path, status=True)
    sorted_directories = sorted(directories, key=lambda x: x[1]['modificationTime'], reverse=True)
    last_directory_name = sorted_directories[0][0]

    return int(last_directory_name)

# Load environment variables from .env
load_dotenv()

# Get the API key (Create a .env file and add API_KEY variable in it)
API_KEY = os.getenv('API_KEY')

# Specify credentials
user_name = 'hicham'
host = 'http://localhost:9870'

# Connect to HDFS
client = InsecureClient(host, user=user_name)

# Get directory number of api last page data retreived
page_num = get_last_api_page(user_name)

if page_num and page_num >= 1:
    page = page_num + 1
else:
    page = 1

print("Fetshing start.")

start_time = datetime.now()
end_time = start_time

while (end_time - start_time) < timedelta(minutes=5):
    print(f"************* PAGE {page} **************")
    # Call the API to fetch data
    MOVIE_ENDPOINT = "https://api.themoviedb.org/3/trending/person/day?api_key={}&language=en-US&page={}"
    response = requests.get(MOVIE_ENDPOINT.format(API_KEY, page))

    actors_list = []
    movies_list = []
    acted_list = []
    if response.status_code == 200:
        actors = response.json()["results"]
        if actors:
            for actor in actors:
                # Check if "name" field exists and is not empty
                if "known_for" in actor and len(actor["known_for"]) > 0:
                    # convert data details to json type
                    data_json = json.dumps(actor)
                    data = json.loads(data_json)
                    # print("data : ", data)

                    url = "https://api.themoviedb.org/3/person/{}?api_key={}&language=en-US"
                    response = requests.get(url.format(data['id'], API_KEY))
                    if response.status_code == 200:
                        actor_details = response.json()

                        # Create actor JSON object
                        actor = {
                            'actor_id': actor_details['id'],
                            'name': actor_details['name'],
                            'gender': actor_details['gender'],
                            'profile_path': actor_details['profile_path'],
                            'birthday': actor_details['birthday'],
                            'deathday': actor_details['deathday'],
                            'department': actor_details['known_for_department'],
                            'place_of_birth': actor_details['place_of_birth'],
                            'popularity': actor_details['popularity'],
                        }
                        actors_list.append(actor)

                        # Create movie JSON objects
                        for movie in data['known_for']:
                            url = "https://api.themoviedb.org/3/movie/{}?api_key={}&language=en-US"
                            response = requests.get(url.format(movie['id'], API_KEY))
                            if response.status_code == 200:
                                movie_details = response.json()
                            
                                movie_obj = {
                                    'movie_id': movie_details['id'],
                                    'title': movie_details['title'],
                                    'budget': movie_details['budget'],
                                    'original_language': movie_details['original_language'],
                                    'original_title': movie_details['original_title'],
                                    'overview': movie_details['overview'],
                                    'poster_path': movie_details['poster_path'],
                                    'genres': movie_details['genres'],
                                    'popularity': movie_details['popularity'],
                                    'release_date': movie_details['release_date'],
                                    'revenue': movie_details['revenue'],
                                    'vote_average': movie_details['vote_average'],
                                    'vote_count': movie_details['vote_count'],
                                    'production_companies': movie_details['production_companies'],
                                    'production_countries': movie_details['production_countries'],
                                }
                                movies_list.append(movie_obj)

                        # Create acted JSON objects
                        for movie in data['known_for']:
                            acted_obj = {
                                'actor_id': actor_details['id'],
                                'movie_id': movie['id']
                            }
                            acted_list.append(acted_obj)
                        break
                    else:
                        print("Actor details not found.")
                else:
                    print("Empty or missing 'actor name' or 'known_for' field. Skipping sending to DB.")
            
            print(f"Data from page {page} has been collected successfully.")

            # Generate dataframes
            df_actors = pd.DataFrame(actors_list)
            df_movies = pd.DataFrame(movies_list)
            df_acted = pd.DataFrame(acted_list)

            # HDFS files path
            actors_filepath = datetime.now().strftime('%d-%m-%Y') + f"/{page}/" + "actors.json"
            movies_filepath = datetime.now().strftime('%d-%m-%Y') + f"/{page}/" + "movies.json"
            acted_filepath = datetime.now().strftime('%d-%m-%Y') + f"/{page}/" + "acted.json"

            # Convert DataFrame to JSON format
            actors_data = df_actors.to_json(orient='records', lines=True)
            movies_data = df_movies.to_json(orient='records', lines=True)
            acted_data = df_acted.to_json(orient='records', lines=True)

            # Upload the JSON data to HDFS
            with client.write(actors_filepath, overwrite=True) as hdfs_file:
                hdfs_file.write(actors_data)

            with client.write(movies_filepath, overwrite=True) as hdfs_file:
                hdfs_file.write(movies_data)

            with client.write(acted_filepath, overwrite=True) as hdfs_file:
                hdfs_file.write(acted_data)

            print("Files saved successfully.")
            print("\n##################################\n")
        else:
            print("Empty data. Skipping sending to DB.")
    else:
        print("Error fetching data from TMDb API, please check the api key or the endpoint url.")

    end_time = datetime.now()
    page = page + 1

print("Fetshing done after 5 minutes.")
# Out:
# Fetshing start.
# ************* PAGE 124 **************
# Data from page 124 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 125 **************
# Data from page 125 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 126 **************
# Empty or missing 'actor name' or 'known_for' field. Skipping sending to DB.
# Data from page 126 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 127 **************
# Data from page 127 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 128 **************
# Data from page 128 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 129 **************
# Data from page 129 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 130 **************
# Data from page 130 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 131 **************
# Data from page 131 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 132 **************
# Data from page 132 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 133 **************
# Data from page 133 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 134 **************
# Data from page 134 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 135 **************
# Data from page 135 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 136 **************
# Empty or missing 'actor name' or 'known_for' field. Skipping sending to DB.
# Data from page 136 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 137 **************
# Data from page 137 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 138 **************
# Data from page 138 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 139 **************
# Data from page 139 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 140 **************
# Data from page 140 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 141 **************
# Data from page 141 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 142 **************
# Data from page 142 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 143 **************
# Data from page 143 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 144 **************
# Data from page 144 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 145 **************
# Data from page 145 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 146 **************
# Data from page 146 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 147 **************
# Data from page 147 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 148 **************
# Data from page 148 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 149 **************
# Data from page 149 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 150 **************
# Data from page 150 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 151 **************
# Data from page 151 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 152 **************
# Data from page 152 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 153 **************
# Data from page 153 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 154 **************
# Data from page 154 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 155 **************
# Data from page 155 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 156 **************
# Data from page 156 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 157 **************
# Data from page 157 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 158 **************
# Data from page 158 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 159 **************
# Data from page 159 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 160 **************
# Data from page 160 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 161 **************
# Data from page 161 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 162 **************
# Data from page 162 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 163 **************
# Data from page 163 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 164 **************
# Data from page 164 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 165 **************
# Data from page 165 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 166 **************
# Data from page 166 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 167 **************
# Data from page 167 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 168 **************
# Data from page 168 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 169 **************
# Data from page 169 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 170 **************
# Data from page 170 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 171 **************
# Data from page 171 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 172 **************
# Data from page 172 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 173 **************
# Data from page 173 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 174 **************
# Data from page 174 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 175 **************
# Data from page 175 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 176 **************
# Data from page 176 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 177 **************
# Data from page 177 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 178 **************
# Data from page 178 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 179 **************
# Data from page 179 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 180 **************
# Data from page 180 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# ************* PAGE 181 **************
# Data from page 181 has been collected successfully.
# Files saved successfully.
#
# ##################################
#
# Fetshing done after 5 minutes.
