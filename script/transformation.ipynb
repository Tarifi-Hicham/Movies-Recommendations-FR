# %%
import pandas as pd
import requests
import json
import os
from hdfs import InsecureClient
from dotenv import load_dotenv
from datetime import datetime, timedelta


# Function to get Actor detail
def get_actors_details(actors_filepath):
    with hdfs_client.read(actors_filepath) as hdfs_file:
        actors_content = hdfs_file.read()
        json_objects = []
        for line in actors_content.splitlines():
            try:
                json_object = json.loads(line)
                json_objects.append(json_object)
            except:
                continue
        return json_objects
    
# Function to get movies details
def get_movies_details(movies_filepath):
    with hdfs_client.read(movies_filepath) as hdfs_file:
        movies_content = hdfs_file.read()
        json_objects = []
        for line in movies_content.splitlines():
            try:
                json_object = json.loads(line)
                json_objects.append(json_object)
            except:
                continue
        return json_objects
    
# Function to get movie and actor relationship
def get_acted_details(acted_filepath):
    with hdfs_client.read(acted_filepath) as hdfs_file:
        acted_content = hdfs_file.read()
        json_objects = []
        for line in acted_content.splitlines():
            try:
                json_object = json.loads(line)
                json_objects.append(json_object)
            except:
                continue
        return json_objects

# Load environment variables from .env
load_dotenv()

# Get the API key (Create a .env file and add API_KEY variable in it)
API_KEY = os.getenv('API_KEY')

# Specify credentials
user_name = 'hicham'
host = 'http://localhost:9870'

# Connect to HDFS
hdfs_client = InsecureClient(host, user=user_name)

# Specify files path directory name as today
hdfs_file_path = f"{datetime.now().strftime('%d-%m-%Y')}"

# Get directories located in today directory
directories = hdfs_client.list(hdfs_file_path, status=True)

# Get directories names to iterate them
directory_names = [directory[1]['pathSuffix'] for directory in directories if directory[1]['type'] == 'DIRECTORY']

actors = []
movies = []
acted = []
for directory in directory_names:
    # HDFS files path
    actors_filepath = hdfs_file_path + f"/{directory}/" + "actors.json"
    movies_filepath = hdfs_file_path + f"/{directory}/" + "movies.json"
    acted_filepath = hdfs_file_path + f"/{directory}/" + "acted.json"

    actors.extend(get_actors_details(actors_filepath))
    movies.extend(get_movies_details(movies_filepath))
    acted.extend(get_acted_details(acted_filepath))

# %%
from geopy.geocoders import Nominatim

# Function to find an element by id
def find_element_by_id(el_list, type, id):
    for el in el_list:
        if type == 'movie' and el['movie_id'] == id:
            return el
        elif type == 'actor' and el['actor_id'] == id:
            return el
    return None

# Function to get departement info by name
def get_department_info(department_name):
    departments = {
        'Writing': {'dep_id': 1, 'name': 'Writing'},
        'Creator': {'dep_id': 2, 'name': 'Creator'},
        'Art': {'dep_id': 3, 'name': 'Art'},
        'Costume & Make-Up': {'dep_id': 4, 'name': 'Costume & Make-Up'},
        'Editing': {'dep_id': 5, 'name': 'Editing'},
        'Directing': {'dep_id': 6, 'name': 'Directing'},
        'Production': {'dep_id': 7, 'name': 'Production'},
        'Camera': {'dep_id': 8, 'name': 'Camera'},
        'Sound': {'dep_id': 9, 'name': 'Sound'},
        'Crew': {'dep_id': 10, 'name': 'Crew'},
        'Acting': {'dep_id': 11, 'name': 'Acting'},
    }
    department = departments.get(department_name)
    return department

# Function to get gender name by id
def get_gender_info(id):
    genders = {
        '0' : 'Not specified',
        '1' : 'Female',
        '2' : 'Male'
    }
    gender = genders.get(id)
    if not gender:
        return genders.get(0)
    return gender

# Function to encode the country name and city name to int code as id
def encode_item(name, length):
    mybytes = name.encode('utf-8')
    myint = int.from_bytes(mybytes, 'little')
    encoded_value = str(myint)[:length]
    return int(encoded_value)

# Correct the name of the country or city to be recognized
def recognize_place_of_birth(place):
    # Manual correction mapping for non-standard place names
    place_name_mapping = {
        "U.S.": "United States",
        "UK": "United Kingdom",
        "USSR (Russia)": "Russia",
        "Paddington (Circle and Hammersmith & City lines)": "Paddington"
    }
    # Manually correct the place of birth if not recognized by the geocoding service
    corrected_place_of_birth = place
    for key, value in place_name_mapping.items():
        corrected_place_of_birth = corrected_place_of_birth.replace(key, value)
    
    return corrected_place_of_birth

# Function to check if the input is city or not
def is_country(text):
    geolocator = Nominatim(user_agent="my_geocoder")
    location = geolocator.geocode(text, exactly_one=True, addressdetails=True, language='en')
    
    if location is not None and 'address' in location.raw:
        address = location.raw
        if 'country' in address and 'city' not in address:
            return True
    
    return False

# Function to get place of birth of actor using geopy library
def get_location_info(place_of_birth):
    if place_of_birth:
        geolocator = Nominatim(user_agent="my_geocoder")
        # Retrieve location information based on place of birth
        location = geolocator.geocode(place_of_birth, exactly_one=True, language='en')
        if location is not None:
            country = location.address.split(',')[-1].strip()
            city = location.address.split(',')[0].strip()
            country = recognize_place_of_birth(country)
            city = recognize_place_of_birth(city)
            # Here I test if the name of the city returned is correct or nah
            if not is_country(city):
                id_country = encode_item(country, 10)
                id_city = encode_item(city, 10)
                if country and city:
                    return {
                        'country': {'id' : id_country, 'name' : country}, 
                        'city': {'id' : id_city, 'name' : city}
                        }
            else:
                id_country = encode_item(country, 10)
                if country and city:
                    return {
                        'country': {'id' : id_country, 'name' : country}, 
                        'city': {'id' : 0, 'name' : 'None'}
                        }
        else:
            # Split the place of birth manually if the geopy didn't recognize the address
            place_of_birth = recognize_place_of_birth(place_of_birth)
            country = place_of_birth.split(',')[-1].strip()
            city = place_of_birth.split(',')[0].strip()
            id_country = encode_item(country, 10)
            id_city = encode_item(city, 10)
            if country and city:
                return {
                    'country': {'id' : id_country, 'name' : country}, 
                    'city': {'id' : id_city, 'name' : city}
                    }
    return None

realisations = []
for act in acted:
    movie = find_element_by_id(movies, 'movie', act.get('movie_id'))
    actor = find_element_by_id(actors, 'actor', act.get('actor_id'))
    if movie and actor:
        realization_object = {
            'actor_id' : act.get('actor_id'),
            'movie_id' : act.get('movie_id'),
            'actor_popularity' : actor.get('popularity'),
            'movie_budget' : movie.get('budget'),
            'movie_revenue' : movie.get('revenue'),
            'movie_popularity' : movie.get('popularity'),
            'movie_vote_average' : movie.get('vote_average'),
            'movie_vote_count' : movie.get('vote_count'),
        }
        # print(realization_object)
    if movie:
        movie_object = {
            'movie_id' : movie.get('movie_id'),
            'title' : movie.get('title'),
            'original_title' : movie.get('original_title'),
            'original_language' : movie.get('original_language'),
            'overview' : movie.get('overview'),
            'poster_path' : movie.get('poster_path'),
            'release_date' : movie.get('release_date'),
        }
        # print(movie)
        for genre in movie.get('genres'):
            movie_genre = {
                'movie_id' : movie.get('movie_id'),
                'genre_id' : genre.get('id')
            }
            genre = {
                'genre_id' : genre.get('id'),
                'name' : genre.get('name')
            }
            # print(genre)
        for company in movie.get('production_companies'):
            movie_prod_company = {
                'movie_id' : movie.get('movie_id'),
                'prod_company_id' : company.get('id')
            }
            production_company = {
                'prod_company_id' : company.get('id'),
                'name' : company.get('name'),
                'logo_path' : company.get('logo_path'),
                'origin_country' : company.get('origin_country'),
            }
            # print(str(movie_prod_company) + "\n" + str(production_company))
        for country in movie.get('production_countries'):
            movie_prod_country = {
                'movie_id' : movie.get('movie_id'),
                'prod_country_id' : country.get('iso_3166_1')
            }
            production_country = {
                'prod_country_id' : country.get('iso_3166_1'),
                'name' : country.get('name')
            }
            # print(str(movie_prod_country) + "\n" + str(production_country))

    if actor:
        dep = get_department_info(actor.get('department'))
        department = {
            'dep_id' : dep.get('dep_id'),
            'name' : dep.get('name'),
        }
        print(department)
        gender = {
            'gender_id' : actor.get('gender'),
            'name' : get_gender_info(str(actor.get('gender'))),
        }
        print(gender)
        location_info = get_location_info(actor.get('place_of_birth'))
        if location_info:
            country = location_info.get('country')
            city = location_info.get('city')
            # Create country and city objects
            country_object = {
                'country_id' : country.get('id'),
                'name' : country.get('name'),
            }
            city_object = {
                'city_id' : city.get('id'),
                'name' : city.get('name'),
            }
            
        else:
            country_object = {
                'country_id' : 0,
                'name' : 'None',
            }
            city_object = {
                'city_id' : 0,
                'name' : 'None',
            }
        # print(actor.get('place_of_birth'))
        print(country_object)
        print(city_object)
        # print("\n")
        actor_object = {
            'actor_id' : actor.get('actor_id'),
            'gender_id' : gender.get('gender_id'),
            'dep_id' : department.get('dep_id'),
            'country_id' : country_object.get('country_id'),
            'city_id' : city_object.get('city_id'),
            'full_name' : actor.get('name'),
            'profile_path' : actor.get('profile_path'),
            'birthday' : actor.get('birthday'),
            'deathday' : actor.get('deathday')
        }
        print(actor_object)
        print("\n")
# Out:
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 933329, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Patrizia Focardi', 'profile_path': '/zA9SIQTskGCUM6MLPgH5al3M5qh.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 933329, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Patrizia Focardi', 'profile_path': '/zA9SIQTskGCUM6MLPgH5al3M5qh.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 933329, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Patrizia Focardi', 'profile_path': '/zA9SIQTskGCUM6MLPgH5al3M5qh.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1797724226, 'name': 'Minnesota'}
# {'actor_id': 1942233, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1797724226, 'full_name': 'SungWon Cho', 'profile_path': '/jh5Au9smnPwfLoPNrcJ2VsJnbhU.jpg', 'birthday': '1990-12-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1797724226, 'name': 'Minnesota'}
# {'actor_id': 1942233, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1797724226, 'full_name': 'SungWon Cho', 'profile_path': '/jh5Au9smnPwfLoPNrcJ2VsJnbhU.jpg', 'birthday': '1990-12-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1797724226, 'name': 'Minnesota'}
# {'actor_id': 1942233, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1797724226, 'full_name': 'SungWon Cho', 'profile_path': '/jh5Au9smnPwfLoPNrcJ2VsJnbhU.jpg', 'birthday': '1990-12-09', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4357286393, 'name': 'Hesse'}
# {'actor_id': 4321598, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4357286393, 'full_name': 'David Roth', 'profile_path': None, 'birthday': '2007-10-27', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4357286393, 'name': 'Hesse'}
# {'actor_id': 4321598, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4357286393, 'full_name': 'David Roth', 'profile_path': None, 'birthday': '2007-10-27', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3462763, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Cinzia Berni', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3462763, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Cinzia Berni', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1087563, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Ayesha Antoine', 'profile_path': '/7EQ1NyUQzUavbUczcufkQG5Sweu.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1087563, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Ayesha Antoine', 'profile_path': '/7EQ1NyUQzUavbUczcufkQG5Sweu.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1087563, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Ayesha Antoine', 'profile_path': '/7EQ1NyUQzUavbUczcufkQG5Sweu.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 4787784538, 'name': 'Tokyo'}
# {'actor_id': 1123401, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 4787784538, 'full_name': 'Yu Kobayashi', 'profile_path': '/q98lvBNhHvxGYfIvfB3YRczsTeE.jpg', 'birthday': '1982-02-05', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 4787784538, 'name': 'Tokyo'}
# {'actor_id': 1123401, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 4787784538, 'full_name': 'Yu Kobayashi', 'profile_path': '/q98lvBNhHvxGYfIvfB3YRczsTeE.jpg', 'birthday': '1982-02-05', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 4787784538, 'name': 'Tokyo'}
# {'actor_id': 1123401, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 4787784538, 'full_name': 'Yu Kobayashi', 'profile_path': '/q98lvBNhHvxGYfIvfB3YRczsTeE.jpg', 'birthday': '1982-02-05', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2746235, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Stéphane Dufault', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2746235, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Stéphane Dufault', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2746235, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Stéphane Dufault', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 2938266749, 'name': 'Korbach'}
# {'actor_id': 1291682, 'gender_id': 2, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 2938266749, 'full_name': 'Matthias Reim', 'profile_path': None, 'birthday': '1957-11-26', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 2938266749, 'name': 'Korbach'}
# {'actor_id': 1291682, 'gender_id': 2, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 2938266749, 'full_name': 'Matthias Reim', 'profile_path': None, 'birthday': '1957-11-26', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 2938266749, 'name': 'Korbach'}
# {'actor_id': 1291682, 'gender_id': 2, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 2938266749, 'full_name': 'Matthias Reim', 'profile_path': None, 'birthday': '1957-11-26', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 94062, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Katy Manning', 'profile_path': '/uTFJ9ZRuuqQuZl38bs7jK7RpS6Q.jpg', 'birthday': '1949-10-14', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 94062, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Katy Manning', 'profile_path': '/uTFJ9ZRuuqQuZl38bs7jK7RpS6Q.jpg', 'birthday': '1949-10-14', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 94062, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Katy Manning', 'profile_path': '/uTFJ9ZRuuqQuZl38bs7jK7RpS6Q.jpg', 'birthday': '1949-10-14', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4837923367, 'name': 'Dusseldorf'}
# {'actor_id': 1306591, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4837923367, 'full_name': 'Heiko Schier', 'profile_path': None, 'birthday': '1954-02-10', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4837923367, 'name': 'Dusseldorf'}
# {'actor_id': 1306591, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4837923367, 'full_name': 'Heiko Schier', 'profile_path': None, 'birthday': '1954-02-10', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4837923367, 'name': 'Dusseldorf'}
# {'actor_id': 1306591, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4837923367, 'full_name': 'Heiko Schier', 'profile_path': None, 'birthday': '1954-02-10', 'deathday': None}
#
#
# {'dep_id': 7, 'name': 'Production'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2390094, 'gender_id': 0, 'dep_id': 7, 'country_id': 0, 'city_id': 0, 'full_name': 'Av', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 1070839438, 'name': 'Apolda'}
# {'actor_id': 38600, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 1070839438, 'full_name': 'Jörg Grünler', 'profile_path': None, 'birthday': '1945-11-09', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 1070839438, 'name': 'Apolda'}
# {'actor_id': 38600, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 1070839438, 'full_name': 'Jörg Grünler', 'profile_path': None, 'birthday': '1945-11-09', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 1070839438, 'name': 'Apolda'}
# {'actor_id': 38600, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 1070839438, 'full_name': 'Jörg Grünler', 'profile_path': None, 'birthday': '1945-11-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1114777280, 'name': 'France'}
# {'city_id': 4956903427, 'name': 'Paris'}
# {'actor_id': 1194533, 'gender_id': 2, 'dep_id': 11, 'country_id': 1114777280, 'city_id': 4956903427, 'full_name': 'Robert Duranton', 'profile_path': None, 'birthday': '1926-09-11', 'deathday': '2005-02-07'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1114777280, 'name': 'France'}
# {'city_id': 4956903427, 'name': 'Paris'}
# {'actor_id': 1194533, 'gender_id': 2, 'dep_id': 11, 'country_id': 1114777280, 'city_id': 4956903427, 'full_name': 'Robert Duranton', 'profile_path': None, 'birthday': '1926-09-11', 'deathday': '2005-02-07'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1114777280, 'name': 'France'}
# {'city_id': 4956903427, 'name': 'Paris'}
# {'actor_id': 1194533, 'gender_id': 2, 'dep_id': 11, 'country_id': 1114777280, 'city_id': 4956903427, 'full_name': 'Robert Duranton', 'profile_path': None, 'birthday': '1926-09-11', 'deathday': '2005-02-07'}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2243998, 'gender_id': 2, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Quentin Papapietro', 'profile_path': '/2T7dwZNoiaNxkewoWd3Li3LZkC6.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2243998, 'gender_id': 2, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Quentin Papapietro', 'profile_path': '/2T7dwZNoiaNxkewoWd3Li3LZkC6.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2243998, 'gender_id': 2, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Quentin Papapietro', 'profile_path': '/2T7dwZNoiaNxkewoWd3Li3LZkC6.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3014022749, 'name': 'Santa Monica'}
# {'actor_id': 59261, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3014022749, 'full_name': 'Hannah Marks', 'profile_path': '/sy5AUrXXeaRYnz0qE3azrZxY0M6.jpg', 'birthday': '1993-04-13', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3014022749, 'name': 'Santa Monica'}
# {'actor_id': 59261, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3014022749, 'full_name': 'Hannah Marks', 'profile_path': '/sy5AUrXXeaRYnz0qE3azrZxY0M6.jpg', 'birthday': '1993-04-13', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3014022749, 'name': 'Santa Monica'}
# {'actor_id': 59261, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3014022749, 'full_name': 'Hannah Marks', 'profile_path': '/sy5AUrXXeaRYnz0qE3azrZxY0M6.jpg', 'birthday': '1993-04-13', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1334765182, 'name': 'Nutley'}
# {'actor_id': 9287, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1334765182, 'full_name': 'Robert Blake', 'profile_path': '/gxhVHS4qhVp1xJiCy9s08ltIiPu.jpg', 'birthday': '1933-09-18', 'deathday': '2023-03-09'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1334765182, 'name': 'Nutley'}
# {'actor_id': 9287, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1334765182, 'full_name': 'Robert Blake', 'profile_path': '/gxhVHS4qhVp1xJiCy9s08ltIiPu.jpg', 'birthday': '1933-09-18', 'deathday': '2023-03-09'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1334765182, 'name': 'Nutley'}
# {'actor_id': 9287, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1334765182, 'full_name': 'Robert Blake', 'profile_path': '/gxhVHS4qhVp1xJiCy9s08ltIiPu.jpg', 'birthday': '1933-09-18', 'deathday': '2023-03-09'}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4741484675, 'name': 'Essen'}
# {'actor_id': 28445, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4741484675, 'full_name': 'Niki Stein', 'profile_path': None, 'birthday': '1961-01-25', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4741484675, 'name': 'Essen'}
# {'actor_id': 28445, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4741484675, 'full_name': 'Niki Stein', 'profile_path': None, 'birthday': '1961-01-25', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 4741484675, 'name': 'Essen'}
# {'actor_id': 28445, 'gender_id': 2, 'dep_id': 6, 'country_id': 3417983690, 'city_id': 4741484675, 'full_name': 'Niki Stein', 'profile_path': None, 'birthday': '1961-01-25', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1177448744, 'name': 'South Korea'}
# {'city_id': 1945207531, 'name': 'Goyang-si'}
# {'actor_id': 2341408, 'gender_id': 2, 'dep_id': 11, 'country_id': 1177448744, 'city_id': 1945207531, 'full_name': 'Lee Do-hyun', 'profile_path': '/1iDRxID6mHf8rftDG0kLWzfXvQA.jpg', 'birthday': '1995-04-11', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1177448744, 'name': 'South Korea'}
# {'city_id': 1945207531, 'name': 'Goyang-si'}
# {'actor_id': 2341408, 'gender_id': 2, 'dep_id': 11, 'country_id': 1177448744, 'city_id': 1945207531, 'full_name': 'Lee Do-hyun', 'profile_path': '/1iDRxID6mHf8rftDG0kLWzfXvQA.jpg', 'birthday': '1995-04-11', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1177448744, 'name': 'South Korea'}
# {'city_id': 1945207531, 'name': 'Goyang-si'}
# {'actor_id': 2341408, 'gender_id': 2, 'dep_id': 11, 'country_id': 1177448744, 'city_id': 1945207531, 'full_name': 'Lee Do-hyun', 'profile_path': '/1iDRxID6mHf8rftDG0kLWzfXvQA.jpg', 'birthday': '1995-04-11', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1334595227, 'name': 'Norway'}
# {'city_id': 1869378383, 'name': 'Oslo'}
# {'actor_id': 18160, 'gender_id': 1, 'dep_id': 11, 'country_id': 1334595227, 'city_id': 1869378383, 'full_name': 'Kristin Holby', 'profile_path': '/mKAawXYcJS3E1FomiN7UuOKQdZZ.jpg', 'birthday': '1951-11-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1334595227, 'name': 'Norway'}
# {'city_id': 1869378383, 'name': 'Oslo'}
# {'actor_id': 18160, 'gender_id': 1, 'dep_id': 11, 'country_id': 1334595227, 'city_id': 1869378383, 'full_name': 'Kristin Holby', 'profile_path': '/mKAawXYcJS3E1FomiN7UuOKQdZZ.jpg', 'birthday': '1951-11-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3571216663, 'name': 'Cedar Rapids'}
# {'actor_id': 109, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3571216663, 'full_name': 'Elijah Wood', 'profile_path': '/7UKRbJBNG7mxBl2QQc5XsAh6F8B.jpg', 'birthday': '1981-01-28', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3571216663, 'name': 'Cedar Rapids'}
# {'actor_id': 109, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3571216663, 'full_name': 'Elijah Wood', 'profile_path': '/7UKRbJBNG7mxBl2QQc5XsAh6F8B.jpg', 'birthday': '1981-01-28', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3571216663, 'name': 'Cedar Rapids'}
# {'actor_id': 109, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3571216663, 'full_name': 'Elijah Wood', 'profile_path': '/7UKRbJBNG7mxBl2QQc5XsAh6F8B.jpg', 'birthday': '1981-01-28', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2704271, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Yeisha Adaraha', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2704271, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Yeisha Adaraha', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2704271, 'gender_id': 1, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Yeisha Adaraha', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3135739039, 'name': 'Chicago'}
# {'actor_id': 92582, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3135739039, 'full_name': 'Alley Mills', 'profile_path': '/9MwgBLOpdaeIKcjUEV72f3S0StQ.jpg', 'birthday': '1951-05-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3135739039, 'name': 'Chicago'}
# {'actor_id': 92582, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3135739039, 'full_name': 'Alley Mills', 'profile_path': '/9MwgBLOpdaeIKcjUEV72f3S0StQ.jpg', 'birthday': '1951-05-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 3135739039, 'name': 'Chicago'}
# {'actor_id': 92582, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 3135739039, 'full_name': 'Alley Mills', 'profile_path': '/9MwgBLOpdaeIKcjUEV72f3S0StQ.jpg', 'birthday': '1951-05-09', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 74869, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Mike Krause', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2712535, 'gender_id': 0, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Liam McGrath', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2712535, 'gender_id': 0, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Liam McGrath', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2712535, 'gender_id': 0, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Liam McGrath', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1851880009, 'name': 'Iran'}
# {'city_id': 1213648103, 'name': 'Tehran'}
# {'actor_id': 1538684, 'gender_id': 1, 'dep_id': 11, 'country_id': 1851880009, 'city_id': 1213648103, 'full_name': 'Alin Sumarwata', 'profile_path': '/85a0Og9K5ExAsucOhEEcFnh5jRj.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1851880009, 'name': 'Iran'}
# {'city_id': 1213648103, 'name': 'Tehran'}
# {'actor_id': 1538684, 'gender_id': 1, 'dep_id': 11, 'country_id': 1851880009, 'city_id': 1213648103, 'full_name': 'Alin Sumarwata', 'profile_path': '/85a0Og9K5ExAsucOhEEcFnh5jRj.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1851880009, 'name': 'Iran'}
# {'city_id': 1213648103, 'name': 'Tehran'}
# {'actor_id': 1538684, 'gender_id': 1, 'dep_id': 11, 'country_id': 1851880009, 'city_id': 1213648103, 'full_name': 'Alin Sumarwata', 'profile_path': '/85a0Og9K5ExAsucOhEEcFnh5jRj.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 2743109017, 'name': 'Atlanta'}
# {'actor_id': 210877, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 2743109017, 'full_name': 'Isabella Acres', 'profile_path': '/zNe900NIdEN9aYQ6ujj1lCUqUqG.jpg', 'birthday': '2001-02-21', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 2743109017, 'name': 'Atlanta'}
# {'actor_id': 210877, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 2743109017, 'full_name': 'Isabella Acres', 'profile_path': '/zNe900NIdEN9aYQ6ujj1lCUqUqG.jpg', 'birthday': '2001-02-21', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 2743109017, 'name': 'Atlanta'}
# {'actor_id': 210877, 'gender_id': 1, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 2743109017, 'full_name': 'Isabella Acres', 'profile_path': '/zNe900NIdEN9aYQ6ujj1lCUqUqG.jpg', 'birthday': '2001-02-21', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 20762, 'gender_id': 2, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Robert Apisa', 'profile_path': '/nk8NuL0rR4QD1vDvrNAyxNmxCfe.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 20762, 'gender_id': 2, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Robert Apisa', 'profile_path': '/nk8NuL0rR4QD1vDvrNAyxNmxCfe.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 20762, 'gender_id': 2, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Robert Apisa', 'profile_path': '/nk8NuL0rR4QD1vDvrNAyxNmxCfe.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 1348463316, 'name': 'Aichi Prefecture'}
# {'actor_id': 2716727, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 1348463316, 'full_name': 'Misaki Hattori', 'profile_path': '/xwzbvrgj0mnOY8gvZb97pIGp40r.jpg', 'birthday': '2006-07-04', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 1348463316, 'name': 'Aichi Prefecture'}
# {'actor_id': 2716727, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 1348463316, 'full_name': 'Misaki Hattori', 'profile_path': '/xwzbvrgj0mnOY8gvZb97pIGp40r.jpg', 'birthday': '2006-07-04', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 1348463316, 'name': 'Aichi Prefecture'}
# {'actor_id': 2716727, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 1348463316, 'full_name': 'Misaki Hattori', 'profile_path': '/xwzbvrgj0mnOY8gvZb97pIGp40r.jpg', 'birthday': '2006-07-04', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 2826886238, 'name': 'Finland'}
# {'city_id': 3136398773, 'name': 'Petsamo'}
# {'actor_id': 106171, 'gender_id': 1, 'dep_id': 11, 'country_id': 2826886238, 'city_id': 3136398773, 'full_name': 'Maila Nurmi', 'profile_path': '/9J4KcIhdIONS1wj75YuHX9l1npg.jpg', 'birthday': '1922-12-11', 'deathday': '2008-01-10'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 2826886238, 'name': 'Finland'}
# {'city_id': 3136398773, 'name': 'Petsamo'}
# {'actor_id': 106171, 'gender_id': 1, 'dep_id': 11, 'country_id': 2826886238, 'city_id': 3136398773, 'full_name': 'Maila Nurmi', 'profile_path': '/9J4KcIhdIONS1wj75YuHX9l1npg.jpg', 'birthday': '1922-12-11', 'deathday': '2008-01-10'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 2826886238, 'name': 'Finland'}
# {'city_id': 3136398773, 'name': 'Petsamo'}
# {'actor_id': 106171, 'gender_id': 1, 'dep_id': 11, 'country_id': 2826886238, 'city_id': 3136398773, 'full_name': 'Maila Nurmi', 'profile_path': '/9J4KcIhdIONS1wj75YuHX9l1npg.jpg', 'birthday': '1922-12-11', 'deathday': '2008-01-10'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1807384, 'gender_id': 2, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Pierre-Xavier Martel', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1807384, 'gender_id': 2, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Pierre-Xavier Martel', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1807384, 'gender_id': 2, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Pierre-Xavier Martel', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1796932703, 'name': 'Indonesia'}
# {'city_id': 1128450303, 'name': 'Special Capital Region of Jakarta'}
# {'actor_id': 2431306, 'gender_id': 1, 'dep_id': 11, 'country_id': 1796932703, 'city_id': 1128450303, 'full_name': 'Nicole Rossi', 'profile_path': '/gb93N4aK91L9vTe1SLQKBxGzGL6.jpg', 'birthday': '2010-03-05', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1796932703, 'name': 'Indonesia'}
# {'city_id': 1128450303, 'name': 'Special Capital Region of Jakarta'}
# {'actor_id': 2431306, 'gender_id': 1, 'dep_id': 11, 'country_id': 1796932703, 'city_id': 1128450303, 'full_name': 'Nicole Rossi', 'profile_path': '/gb93N4aK91L9vTe1SLQKBxGzGL6.jpg', 'birthday': '2010-03-05', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1796932703, 'name': 'Indonesia'}
# {'city_id': 1128450303, 'name': 'Special Capital Region of Jakarta'}
# {'actor_id': 2431306, 'gender_id': 1, 'dep_id': 11, 'country_id': 1796932703, 'city_id': 1128450303, 'full_name': 'Nicole Rossi', 'profile_path': '/gb93N4aK91L9vTe1SLQKBxGzGL6.jpg', 'birthday': '2010-03-05', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 5213308872, 'name': 'Göttingen'}
# {'actor_id': 8797, 'gender_id': 1, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 5213308872, 'full_name': 'Juliane Köhler', 'profile_path': '/v2eHSiEdAhu2mJWxEwa3Sqxtgg1.jpg', 'birthday': '1965-08-06', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 5213308872, 'name': 'Göttingen'}
# {'actor_id': 8797, 'gender_id': 1, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 5213308872, 'full_name': 'Juliane Köhler', 'profile_path': '/v2eHSiEdAhu2mJWxEwa3Sqxtgg1.jpg', 'birthday': '1965-08-06', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 5213308872, 'name': 'Göttingen'}
# {'actor_id': 8797, 'gender_id': 1, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 5213308872, 'full_name': 'Juliane Köhler', 'profile_path': '/v2eHSiEdAhu2mJWxEwa3Sqxtgg1.jpg', 'birthday': '1965-08-06', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 4932743986, 'name': 'Portsmouth'}
# {'actor_id': 1181339, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 4932743986, 'full_name': 'Melvin Gregg', 'profile_path': '/tIeYOezPPBpUmVuzYO7idcWPuUz.jpg', 'birthday': '1988-09-22', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 4932743986, 'name': 'Portsmouth'}
# {'actor_id': 1181339, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 4932743986, 'full_name': 'Melvin Gregg', 'profile_path': '/tIeYOezPPBpUmVuzYO7idcWPuUz.jpg', 'birthday': '1988-09-22', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 4932743986, 'name': 'Portsmouth'}
# {'actor_id': 1181339, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 4932743986, 'full_name': 'Melvin Gregg', 'profile_path': '/tIeYOezPPBpUmVuzYO7idcWPuUz.jpg', 'birthday': '1988-09-22', 'deathday': None}
#
#
# {'dep_id': 7, 'name': 'Production'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1213817551, 'name': 'Sweden'}
# {'city_id': 2018508682, 'name': 'Stockholm'}
# {'actor_id': 1370760, 'gender_id': 1, 'dep_id': 7, 'country_id': 1213817551, 'city_id': 2018508682, 'full_name': 'Leiki Veskimets', 'profile_path': '/qGE7h4xy2iOWan2hFp7rJQX2MGb.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 7, 'name': 'Production'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1213817551, 'name': 'Sweden'}
# {'city_id': 2018508682, 'name': 'Stockholm'}
# {'actor_id': 1370760, 'gender_id': 1, 'dep_id': 7, 'country_id': 1213817551, 'city_id': 2018508682, 'full_name': 'Leiki Veskimets', 'profile_path': '/qGE7h4xy2iOWan2hFp7rJQX2MGb.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 7, 'name': 'Production'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1213817551, 'name': 'Sweden'}
# {'city_id': 2018508682, 'name': 'Stockholm'}
# {'actor_id': 1370760, 'gender_id': 1, 'dep_id': 7, 'country_id': 1213817551, 'city_id': 2018508682, 'full_name': 'Leiki Veskimets', 'profile_path': '/qGE7h4xy2iOWan2hFp7rJQX2MGb.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1213817551, 'name': 'Sweden'}
# {'city_id': 4785771891, 'name': 'Malmo'}
# {'actor_id': 5961, 'gender_id': 1, 'dep_id': 11, 'country_id': 1213817551, 'city_id': 4785771891, 'full_name': 'Anita Ekberg', 'profile_path': '/x6VlAnJbBbtIhCUfhWnERT84BiR.jpg', 'birthday': '1931-09-29', 'deathday': '2015-01-11'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1213817551, 'name': 'Sweden'}
# {'city_id': 4785771891, 'name': 'Malmo'}
# {'actor_id': 5961, 'gender_id': 1, 'dep_id': 11, 'country_id': 1213817551, 'city_id': 4785771891, 'full_name': 'Anita Ekberg', 'profile_path': '/x6VlAnJbBbtIhCUfhWnERT84BiR.jpg', 'birthday': '1931-09-29', 'deathday': '2015-01-11'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1213817551, 'name': 'Sweden'}
# {'city_id': 4785771891, 'name': 'Malmo'}
# {'actor_id': 5961, 'gender_id': 1, 'dep_id': 11, 'country_id': 1213817551, 'city_id': 4785771891, 'full_name': 'Anita Ekberg', 'profile_path': '/x6VlAnJbBbtIhCUfhWnERT84BiR.jpg', 'birthday': '1931-09-29', 'deathday': '2015-01-11'}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 4350194, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Ggggggggggg', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 2219608046, 'name': 'United Kingdom'}
# {'city_id': 1214188208, 'name': 'Cricklewood'}
# {'actor_id': 2959, 'gender_id': 2, 'dep_id': 11, 'country_id': 2219608046, 'city_id': 1214188208, 'full_name': 'Kayvan Novak', 'profile_path': '/2cJuw1nGFHyJTMj8YIh91cvErSm.jpg', 'birthday': '1978-11-23', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 2219608046, 'name': 'United Kingdom'}
# {'city_id': 1214188208, 'name': 'Cricklewood'}
# {'actor_id': 2959, 'gender_id': 2, 'dep_id': 11, 'country_id': 2219608046, 'city_id': 1214188208, 'full_name': 'Kayvan Novak', 'profile_path': '/2cJuw1nGFHyJTMj8YIh91cvErSm.jpg', 'birthday': '1978-11-23', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 2219608046, 'name': 'United Kingdom'}
# {'city_id': 1214188208, 'name': 'Cricklewood'}
# {'actor_id': 2959, 'gender_id': 2, 'dep_id': 11, 'country_id': 2219608046, 'city_id': 1214188208, 'full_name': 'Kayvan Novak', 'profile_path': '/2cJuw1nGFHyJTMj8YIh91cvErSm.jpg', 'birthday': '1978-11-23', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 4478684, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Alfred Wainwright', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 4478684, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Alfred Wainwright', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 4478684, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Alfred Wainwright', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1616167, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'David Korins', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1616167, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'David Korins', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1616167, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'David Korins', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1324791, 'gender_id': 0, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Gillian Murphy', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1324791, 'gender_id': 0, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Gillian Murphy', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3082592, 'gender_id': 2, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Jacob McKee', 'profile_path': '/1Ey5XFlZT2gw6vSZKDIRWHMhaA8.jpg', 'birthday': '1993-03-24', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3082592, 'gender_id': 2, 'dep_id': 6, 'country_id': 0, 'city_id': 0, 'full_name': 'Jacob McKee', 'profile_path': '/1Ey5XFlZT2gw6vSZKDIRWHMhaA8.jpg', 'birthday': '1993-03-24', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 6306294308, 'name': 'Monmouth County'}
# {'actor_id': 1056523, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 6306294308, 'full_name': "John D'Leo", 'profile_path': '/do0YtjRWmQyVvQf8S5oAMEGw0Bn.jpg', 'birthday': '1995-08-31', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 6306294308, 'name': 'Monmouth County'}
# {'actor_id': 1056523, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 6306294308, 'full_name': "John D'Leo", 'profile_path': '/do0YtjRWmQyVvQf8S5oAMEGw0Bn.jpg', 'birthday': '1995-08-31', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 6306294308, 'name': 'Monmouth County'}
# {'actor_id': 1056523, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 6306294308, 'full_name': "John D'Leo", 'profile_path': '/do0YtjRWmQyVvQf8S5oAMEGw0Bn.jpg', 'birthday': '1995-08-31', 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 22010, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Jerie Kelter', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 22010, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Jerie Kelter', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 22010, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Jerie Kelter', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2738778, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Raf Lydon', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2738778, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Raf Lydon', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 2738778, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Raf Lydon', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 2262346033, 'name': 'Nagasaki Prefecture'}
# {'actor_id': 1139912, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 2262346033, 'full_name': 'Toa Yukinari', 'profile_path': '/aR11JLaHVeTM1RgGULsU9zIiaZs.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 2262346033, 'name': 'Nagasaki Prefecture'}
# {'actor_id': 1139912, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 2262346033, 'full_name': 'Toa Yukinari', 'profile_path': '/aR11JLaHVeTM1RgGULsU9zIiaZs.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 2262346033, 'name': 'Nagasaki Prefecture'}
# {'actor_id': 1139912, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 2262346033, 'full_name': 'Toa Yukinari', 'profile_path': '/aR11JLaHVeTM1RgGULsU9zIiaZs.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 4787784538, 'name': 'Tokyo'}
# {'actor_id': 2359492, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 4787784538, 'full_name': 'Fairouz Ai', 'profile_path': '/coFu6WOVBZvqd1fw89vbHkiC0zB.jpg', 'birthday': '1993-07-06', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 4787784538, 'name': 'Tokyo'}
# {'actor_id': 2359492, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 4787784538, 'full_name': 'Fairouz Ai', 'profile_path': '/coFu6WOVBZvqd1fw89vbHkiC0zB.jpg', 'birthday': '1993-07-06', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 4787784538, 'name': 'Tokyo'}
# {'actor_id': 2359492, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 4787784538, 'full_name': 'Fairouz Ai', 'profile_path': '/coFu6WOVBZvqd1fw89vbHkiC0zB.jpg', 'birthday': '1993-07-06', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3646132, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Pedro Maccarone', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3646132, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Pedro Maccarone', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3646132, 'gender_id': 0, 'dep_id': 11, 'country_id': 0, 'city_id': 0, 'full_name': 'Pedro Maccarone', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1529179, 'gender_id': 2, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Steve Olson', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1529179, 'gender_id': 2, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Steve Olson', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 1529179, 'gender_id': 2, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Steve Olson', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1058020617, 'name': 'Los Angeles County'}
# {'actor_id': 51392, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1058020617, 'full_name': 'Justin Berfield', 'profile_path': '/1FRN8DKGUcCSLwQlZaIpwJkk5jT.jpg', 'birthday': '1986-02-25', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1058020617, 'name': 'Los Angeles County'}
# {'actor_id': 51392, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1058020617, 'full_name': 'Justin Berfield', 'profile_path': '/1FRN8DKGUcCSLwQlZaIpwJkk5jT.jpg', 'birthday': '1986-02-25', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 1058020617, 'name': 'Los Angeles County'}
# {'actor_id': 51392, 'gender_id': 2, 'dep_id': 11, 'country_id': 9142637370, 'city_id': 1058020617, 'full_name': 'Justin Berfield', 'profile_path': '/1FRN8DKGUcCSLwQlZaIpwJkk5jT.jpg', 'birthday': '1986-02-25', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 2911777108, 'name': 'Hamburg'}
# {'actor_id': 66620, 'gender_id': 1, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 2911777108, 'full_name': 'Angela Merkel', 'profile_path': '/fjlqfSwhiRpwgsEtzJ8X004NpBw.jpg', 'birthday': '1954-07-17', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 2911777108, 'name': 'Hamburg'}
# {'actor_id': 66620, 'gender_id': 1, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 2911777108, 'full_name': 'Angela Merkel', 'profile_path': '/fjlqfSwhiRpwgsEtzJ8X004NpBw.jpg', 'birthday': '1954-07-17', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 3417983690, 'name': 'Germany'}
# {'city_id': 2911777108, 'name': 'Hamburg'}
# {'actor_id': 66620, 'gender_id': 1, 'dep_id': 11, 'country_id': 3417983690, 'city_id': 2911777108, 'full_name': 'Angela Merkel', 'profile_path': '/fjlqfSwhiRpwgsEtzJ8X004NpBw.jpg', 'birthday': '1954-07-17', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 2219608046, 'name': 'United Kingdom'}
# {'city_id': 5215162895, 'name': 'Paddington'}
# {'actor_id': 6730, 'gender_id': 2, 'dep_id': 11, 'country_id': 2219608046, 'city_id': 5215162895, 'full_name': 'Sacha Baron Cohen', 'profile_path': '/8J2LxfW3owPTc9OzbBoUbADFOBb.jpg', 'birthday': '1971-10-13', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 2219608046, 'name': 'United Kingdom'}
# {'city_id': 5215162895, 'name': 'Paddington'}
# {'actor_id': 6730, 'gender_id': 2, 'dep_id': 11, 'country_id': 2219608046, 'city_id': 5215162895, 'full_name': 'Sacha Baron Cohen', 'profile_path': '/8J2LxfW3owPTc9OzbBoUbADFOBb.jpg', 'birthday': '1971-10-13', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 2219608046, 'name': 'United Kingdom'}
# {'city_id': 5215162895, 'name': 'Paddington'}
# {'actor_id': 6730, 'gender_id': 2, 'dep_id': 11, 'country_id': 2219608046, 'city_id': 5215162895, 'full_name': 'Sacha Baron Cohen', 'profile_path': '/8J2LxfW3owPTc9OzbBoUbADFOBb.jpg', 'birthday': '1971-10-13', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 8837289192, 'name': 'Saitama Prefecture'}
# {'actor_id': 1781173, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 8837289192, 'full_name': 'Chihiro Kawakami', 'profile_path': '/mOKJC6gBsz93Ccu5FYyrRq5YmH5.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 8837289192, 'name': 'Saitama Prefecture'}
# {'actor_id': 1781173, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 8837289192, 'full_name': 'Chihiro Kawakami', 'profile_path': '/mOKJC6gBsz93Ccu5FYyrRq5YmH5.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 8837289192, 'name': 'Saitama Prefecture'}
# {'actor_id': 1781173, 'gender_id': 1, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 8837289192, 'full_name': 'Chihiro Kawakami', 'profile_path': '/mOKJC6gBsz93Ccu5FYyrRq5YmH5.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 3, 'name': 'Art'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 4228440, 'gender_id': 0, 'dep_id': 3, 'country_id': 0, 'city_id': 0, 'full_name': 'Astrid Maria Sætren', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1214138394, 'name': 'Switzerland'}
# {'city_id': 4741485312, 'name': 'Olten'}
# {'actor_id': 232959, 'gender_id': 2, 'dep_id': 6, 'country_id': 1214138394, 'city_id': 4741485312, 'full_name': 'Baran bo Odar', 'profile_path': '/3CfxoYPDPgFZ6jJMBOXCO5zhhEQ.jpg', 'birthday': '1978-04-18', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1214138394, 'name': 'Switzerland'}
# {'city_id': 4741485312, 'name': 'Olten'}
# {'actor_id': 232959, 'gender_id': 2, 'dep_id': 6, 'country_id': 1214138394, 'city_id': 4741485312, 'full_name': 'Baran bo Odar', 'profile_path': '/3CfxoYPDPgFZ6jJMBOXCO5zhhEQ.jpg', 'birthday': '1978-04-18', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 1214138394, 'name': 'Switzerland'}
# {'city_id': 4741485312, 'name': 'Olten'}
# {'actor_id': 232959, 'gender_id': 2, 'dep_id': 6, 'country_id': 1214138394, 'city_id': 4741485312, 'full_name': 'Baran bo Odar', 'profile_path': '/3CfxoYPDPgFZ6jJMBOXCO5zhhEQ.jpg', 'birthday': '1978-04-18', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 2742333815, 'name': 'Tsuyama'}
# {'actor_id': 552683, 'gender_id': 2, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 2742333815, 'full_name': 'Hochu Otsuka', 'profile_path': '/ouMRSpccmkS6iOMVkSc4fEOBiN2.jpg', 'birthday': '1954-05-19', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 2742333815, 'name': 'Tsuyama'}
# {'actor_id': 552683, 'gender_id': 2, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 2742333815, 'full_name': 'Hochu Otsuka', 'profile_path': '/ouMRSpccmkS6iOMVkSc4fEOBiN2.jpg', 'birthday': '1954-05-19', 'deathday': None}
#
#
# {'dep_id': 11, 'name': 'Acting'}
# {'gender_id': 2, 'name': 'Male'}
# {'country_id': 4740811574, 'name': 'Japan'}
# {'city_id': 2742333815, 'name': 'Tsuyama'}
# {'actor_id': 552683, 'gender_id': 2, 'dep_id': 11, 'country_id': 4740811574, 'city_id': 2742333815, 'full_name': 'Hochu Otsuka', 'profile_path': '/ouMRSpccmkS6iOMVkSc4fEOBiN2.jpg', 'birthday': '1954-05-19', 'deathday': None}
#
#
# {'dep_id': 5, 'name': 'Editing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4742143959, 'name': 'Spain'}
# {'city_id': 4742143959, 'name': 'Spain'}
# {'actor_id': 97082, 'gender_id': 1, 'dep_id': 5, 'country_id': 4742143959, 'city_id': 4742143959, 'full_name': 'María Luisa García', 'profile_path': '/voGJtPIDYGcFUGtLmC1b9xtICtH.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 5, 'name': 'Editing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4742143959, 'name': 'Spain'}
# {'city_id': 4742143959, 'name': 'Spain'}
# {'actor_id': 97082, 'gender_id': 1, 'dep_id': 5, 'country_id': 4742143959, 'city_id': 4742143959, 'full_name': 'María Luisa García', 'profile_path': '/voGJtPIDYGcFUGtLmC1b9xtICtH.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 5, 'name': 'Editing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 4742143959, 'name': 'Spain'}
# {'city_id': 4742143959, 'name': 'Spain'}
# {'actor_id': 97082, 'gender_id': 1, 'dep_id': 5, 'country_id': 4742143959, 'city_id': 4742143959, 'full_name': 'María Luisa García', 'profile_path': '/voGJtPIDYGcFUGtLmC1b9xtICtH.jpg', 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 7, 'name': 'Production'}
# {'gender_id': 0, 'name': 'Not specified'}
# {'country_id': 0, 'name': 'None'}
# {'city_id': 0, 'name': 'None'}
# {'actor_id': 3241193, 'gender_id': 0, 'dep_id': 7, 'country_id': 0, 'city_id': 0, 'full_name': 'Maria Garcia-Quezada', 'profile_path': None, 'birthday': None, 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1177448744, 'name': 'South Korea'}
# {'city_id': 1177448744, 'name': 'South Korea'}
# {'actor_id': 1180430, 'gender_id': 1, 'dep_id': 6, 'country_id': 1177448744, 'city_id': 1177448744, 'full_name': 'Kim Eun-kyung', 'profile_path': '/uiYAMmV2lGLb5RCYAB2Os6E7erq.jpg', 'birthday': '1978-01-01', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1177448744, 'name': 'South Korea'}
# {'city_id': 1177448744, 'name': 'South Korea'}
# {'actor_id': 1180430, 'gender_id': 1, 'dep_id': 6, 'country_id': 1177448744, 'city_id': 1177448744, 'full_name': 'Kim Eun-kyung', 'profile_path': '/uiYAMmV2lGLb5RCYAB2Os6E7erq.jpg', 'birthday': '1978-01-01', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 1177448744, 'name': 'South Korea'}
# {'city_id': 1177448744, 'name': 'South Korea'}
# {'actor_id': 1180430, 'gender_id': 1, 'dep_id': 6, 'country_id': 1177448744, 'city_id': 1177448744, 'full_name': 'Kim Eun-kyung', 'profile_path': '/uiYAMmV2lGLb5RCYAB2Os6E7erq.jpg', 'birthday': '1978-01-01', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 4528066665, 'name': 'Miami'}
# {'actor_id': 56383, 'gender_id': 1, 'dep_id': 6, 'country_id': 9142637370, 'city_id': 4528066665, 'full_name': 'Kelly Reichardt', 'profile_path': '/j97hMhlRhcaHWgn9MQ78E0ft57U.jpg', 'birthday': '1964-03-03', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 4528066665, 'name': 'Miami'}
# {'actor_id': 56383, 'gender_id': 1, 'dep_id': 6, 'country_id': 9142637370, 'city_id': 4528066665, 'full_name': 'Kelly Reichardt', 'profile_path': '/j97hMhlRhcaHWgn9MQ78E0ft57U.jpg', 'birthday': '1964-03-03', 'deathday': None}
#
#
# {'dep_id': 6, 'name': 'Directing'}
# {'gender_id': 1, 'name': 'Female'}
# {'country_id': 9142637370, 'name': 'United States'}
# {'city_id': 4528066665, 'name': 'Miami'}
# {'actor_id': 56383, 'gender_id': 1, 'dep_id': 6, 'country_id': 9142637370, 'city_id': 4528066665, 'full_name': 'Kelly Reichardt', 'profile_path': '/j97hMhlRhcaHWgn9MQ78E0ft57U.jpg', 'birthday': '1964-03-03', 'deathday': None}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 181
#     178 if actor:
#     179     dep = get_department_info(actor.get('department'))
#     180     department = {
# --> 181         'dep_id' : dep.get('dep_id'),
#     182         'name' : dep.get('name'),
#     183     }
#     184     print(department)
#     185     gender = {
#     186         'gender_id' : actor.get('gender'),
#     187         'name' : get_gender_info(str(actor.get('gender'))),
#     188     }
#
# AttributeError: 'NoneType' object has no attribute 'get'
